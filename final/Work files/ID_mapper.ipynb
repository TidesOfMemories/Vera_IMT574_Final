# %%
import pandas as pd
import requests
import json

# %%
df = pd.read_csv('./finance_in_USD.csv')
df_us = df[df['country'].apply(lambda row: 'us' in row if pd.notnull(row) else False)]

# %%
print(any(df_us['country'].isna()))
print(df_us.shape)
# Out:
# False
# (1692, 5)

# %%
df_us = df_us.drop(columns=['Unnamed: 0'])

# %%
df_us = df_us.reset_index(drop = True)
print(df_us.iloc[80:100, :])
# Out:
#          mid        budget      box_office      country
# 80    873886    $4,000,000      $2,022,849           us
# 81    879870   $60,000,000    $204,594,016           us
# 82    881320   $30,000,000    $108,943,221        us au
# 83    882977   $15,000,000     $57,824,674     us ae gb
# 84    884726   $70,000,000     $17,001,027        us in
# 85    884732   $23,000,000     $80,171,596           us
# 86    892318   $30,000,000     $82,148,538           us
# 87    892769  $165,000,000    $494,878,759        us fr
# 88    892791  $165,000,000    $752,600,867        us fr
# 89    903624  $180,000,000  $1,021,103,568        nz us
# 90    905372   $38,000,000     $31,505,287        ca us
# 91  10195452           NaN      $7,377,913        it us
# 92   1020072   $20,000,000     $66,787,908     gb fr us
# 93  10204998        $3,000          $5,000           us
# 94   1240982   $49,900,000     $24,856,478           us
# 95  12412888  $110,000,000    $402,656,846        us jp
# ...

# %%
df_us[df_us['mid'] == 10195452].index
# Out:
# Index([91], dtype='int64')

# %%
id_map = {}
# i = 0
for mid in df_us['mid'][:91]:
    url = f"https://api.themoviedb.org/3/find/tt0{mid}?external_source=imdb_id"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyZjA5OGU5ODBhNjU2ZTg1YzFiMjFlNDU5OGUxOWZmZiIsInN1YiI6IjY1ZDkwNzM5YTA2NjQ1MDE3Yjg4ZGVjZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.gNHcTixALd8eTGdbED5S1sm5XZFLJZBectiQHzeP8YA"
    }

    response = requests.get(url, headers=headers)

    result_dic = json.loads(response.text)
    id_map[mid] = result_dic['movie_results'][0]['id']
    # i =+ 1

# %%
print(id_map)
print(len(id_map))
# Out:
# {293429: 460465, 359950: 116745, 369610: 135397, 376136: 23514, 383010: 76489, 398286: 38757, 401729: 49529, 409847: 49849, 427152: 38778, 429493: 34544, 431021: 77883, 433035: 39254, 435761: 10193, 437086: 399579, 443272: 72976, 446029: 22538, 448115: 287947, 448694: 417859, 451279: 297762, 454876: 87827, 455407: 29427, 455944: 156022, 458339: 1771, 458481: 189, 460890: 95608, 464154: 43593, 470752: 264660, 471042: 59108, 472181: 41513, 472399: 27582, 473075: 9543, 475290: 270487, 477080: 44048, 477302: 64685, 478304: 8967, 478970: 102899, 479997: 23047, 480687: 48988, 481499: 49519, 485985: 72431, 490215: 68730, 491152: 49022, 493405: 417644, 498381: 14564, 758752: 43347, 765446: 68179, 770802: 89708, 770828: 49521, 780504: 64690, 780653: 7978, 787474: 170687, 787524: 353326, 790636: 152532, 790724: 75780, 790736: 49524, 795461: 4258, 800320: 18823, 800369: 10195, 803096: 68735, 808510: 23023, 810819: 306819, 810913: 71880, 814255: 32657, 816442: 203833, 816462: 37430, 816692: 1573
# ...

# %%
id_map_2 = {}
for mid in df_us['mid'][91:]:
    url = f"https://api.themoviedb.org/3/find/tt{mid}?external_source=imdb_id"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyZjA5OGU5ODBhNjU2ZTg1YzFiMjFlNDU5OGUxOWZmZiIsInN1YiI6IjY1ZDkwNzM5YTA2NjQ1MDE3Yjg4ZGVjZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.gNHcTixALd8eTGdbED5S1sm5XZFLJZBectiQHzeP8YA"
    }

    response = requests.get(url, headers=headers)

    result_dic = json.loads(response.text)
    try:
        id_map_2[mid] = result_dic['movie_results'][0]['id']
    except IndexError:
        id_map_2[mid] = 'na'

# %%
print(id_map_2)
print(len(id_map_2))
# Out:
# {10195452: 621476, 1020072: 273895, 10204998: 788584, 1240982: 38319, 12412888: 675353, 1242432: 43947, 1243957: 37710, 1243974: 222936, 1245492: 109414, 1245526: 39514, 1247667: 27584, 1250777: 23483, 1253863: 53182, 1253864: 37958, 1255919: 426563, 1258972: 97430, 12593682: 718930, 1259521: 22970, 1259528: 449443, 1261945: 37786, 1262416: 41446, 1023114: 49009, 1265990: 49950, 1267297: 184315, 1270797: 335983, 1270798: 49538, 1272878: 136400, 1274300: 44638, 1276104: 59967, 1277953: 80321, 1279935: 35056, 12801262: 508943, 1282140: 37735, 1284575: 52449, 1285009: 371608, 1285016: 37799, 1287468: 39691, 1288558: 109428, 1289401: 43074, 1291150: 98566, 1024648: 68734, 1025100: 453405, 1291570: 339527, 1291584: 59440, 1292566: 259694, 1293847: 47971, 1294226: 35690, 1294688: 23830, 1296464: 520894, 1298644: 449562, 1298649: 80035, 1298650: 1865, 1300854: 68721, 1302006: 398978, 1302011: 49444, 1302067: 41515, 1305798: 365101, 13067548: 'na', 1306980: 40807, 13129670: 759378, 1314655: 
# ...

# %%
id_map.update(id_map_2)
print(len(id_map))
# Out:
# 1692

# %%
df_us['tmdb_id'] = df_us['mid'].astype(int).map(id_map)
# df_us['tmdb_id'] = df_us['mid'].astype(int).map(id_map_2)

# %%
df_us.head(50)
# Out:
#        mid        budget      box_office  \
# 0   293429   $55,000,000     $83,601,013
# 1   359950   $90,000,000    $188,133,322
# 2   369610  $150,000,000  $1,648,854,864
# 3   376136   $45,000,000     $21,544,732
# 4   383010           NaN     $54,819,301
# 5   398286  $260,000,000    $591,794,936
# 6   401729  $250,000,000    $284,139,100
# 7   409847  $163,000,000    $174,822,325
# 8   427152           NaN     $86,855,739
# 9   429493  $110,000,000    $177,238,796
# 10  431021   $14,000,000     $85,446,075
# 11  433035  $110,000,000    $299,268,508
# 12  435761  $190,000,000  $1,068,879,522
# 13  437086  $170,000,000    $404,852,543
# 14  443272   $65,000,000    $275,293,450
# 15  446029   $60,000,000    $132,000,000
# 16  448115  $100,000,000    $365,971,656
# 17  448694  $130,000,000    $554,987,477
# 18  451279  $149,000,000    $821,763,408
# 19  454876  $120,000,000    $609,016,565
# 20  455407   $20,000,000     $56,445,534
# 21  455944   $55,000,000    $192,330,738
# ...

# %%
df_us.to_csv('./finance_us_final.csv')

# %%
len(df_us[df_us['tmdb_id'] == 'na'])
# Out:
# 70
